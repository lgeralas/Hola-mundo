# %% [markdown]
# <a href="https://colab.research.google.com/github/lgeralas/Hola-mundo/blob/main/Hola_mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridas
#pip (para instalar alguna librería)
import pandas as pd #pd para abreviar
import numpy as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cargar archivo csv desde seaborn
df=sns.load_dataset(name='car_crashes')

# %%
#Imprimir las primeras filas (horizontal) o registros del Dataframe
df.head(3)#tu eliges el número en head(n)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ

# %%
#Imprimir las últimas filas (horizontal) o registros del Dataframe
df.tail(5)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
#para obtener información del Dataframe
df.info
